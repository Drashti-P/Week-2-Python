# %% [markdown]
# 1. Load in the dataset train_viz.csv.
# 2. Create a scatter plot of duration vs. price. Segment by destination.
# 3. Create a barplot of fare counts.
# 4. Create a box & whisker plot of price with respect to destination.
# 5. Create a histogram of duration.
# 6. Compare this to a histogram of price.
# 7. Create a violin plot of price with respect to destination.
# 8. Create a heatmap of the correlation between columns.
# 9. Create a proportional stacked bar plot of vehicle_class by destination)

# %%
#1
import pandas as pd
data = pd.read_csv(r"C:\Users\Admin\Documents\Course Files\QADHPYTHON\data\train_viz.csv")

# %%
data.head(5)
# Out:
#    origin destination            departure              arrival vehicle_class  \
# 0  MADRID   BARCELONA  2019-04-12 07:15:00  2019-04-12 16:37:00       Turista
# 1  MADRID     SEVILLA  2019-04-12 09:00:00  2019-04-12 11:38:00       Turista
# 2  MADRID     SEVILLA  2019-04-12 11:05:00  2019-04-12 13:41:00    Preferente
# 3  MADRID     SEVILLA  2019-04-12 12:00:00  2019-04-12 14:32:00       Turista
# 4  MADRID   BARCELONA  2019-04-12 12:30:00  2019-04-12 15:30:00       Turista
#
#      price        fare  duration
# 0  43.2500  Adulto ida       562
# 1  76.3000    Flexible       158
# 2  87.4000    Flexible       156
# 3  76.3000    Flexible       152
# 4  71.4938    Flexible       180

# %%
data.dtypes
# Out:
# origin            object
# destination       object
# departure         object
# arrival           object
# vehicle_class     object
# price            float64
# fare              object
# duration           int64
# dtype: object

# %%
#2 Scatter plot - Duration vs price
import seaborn as sns
plot_duration_v_price = sns.scatterplot(data = data, x="duration", y="price", style = "destination")
plot_duration_v_price
# Out:
# <Axes: xlabel='duration', ylabel='price'>

# %%
farecount = sns.countplot(x = "fare", data = data)
farecount.set_xticklabels(farecount.get_xticklabels(), rotation = 90)

farecount.show
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5588\90709849.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   farecount.set_xticklabels(farecount.get_xticklabels(), rotation = 90)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 4
#       1 farecount = sns.countplot(x = "fare", data = data)
#       2 farecount.set_xticklabels(farecount.get_xticklabels(), rotation = 90)
# ----> 4 farecount.show
#
# AttributeError: 'Axes' object has no attribute 'show'

# %%
#4
data["destination"].unique()
# Out:
# array(['BARCELONA', 'SEVILLA', 'PONFERRADA'], dtype=object)

# %%
#box and whisker plot - Barcelona
price_v_destination = sns.boxplot(data=data,x = "price", y="destination")

# %%
#5
duration = sns.histplot(data = data, x='duration')

# %%
#5 and 6
price_histogram = sns.histplot(data = data, x='price')

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

sns.histplot(data=data, x='price', color='blue', ax=axes[0])
axes[0].set_title('Price Histogram')

sns.histplot(data=data, x='duration', color='red', ax=axes[1])
axes[1].set_title('Duration Histogram')

plt.show()

# %%
print("The comparison of the histograms shows: the duration is larger than price - which makes sense realistically; there is a greater spread for duration, and the modal price is £75 and the modal duration is 1h 40mins.")  .")
# Out:
#   Cell In[47], line 1
#     print("The comparison of the histograms shows: the duration is larger than price - which makes sense realistically; there is a greater spread for duration, and the modal price is £75 and the modal duration is 1h 40mins.")  .")
#                                                                                                                                                                                                                                     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
#7
sns.violinplot(data = data, x='price', y='destination');

# %%
#8
columns_corr = data.corr(numeric_only=True)
sns.heatmap(columns_corr,cmap = "coolwarm", annot=True)
# Out:
# <Axes: >

# %%
data.plot(kind="bar", stacked=True, x = "vehicle_class")
