# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\Admin\Documents\Course Files\QADHPYTHON\data\renfe_trains.csv")

# %%
data.head()
# Out:
#   company  origin destination            departure              arrival  \
# 0   renfe  MADRID     SEVILLA  2019-05-07 19:00:00  2019-05-07 21:38:00
# 1   renfe  MADRID     SEVILLA  2019-05-07 21:25:00  2019-05-08 00:10:00
# 2   renfe  MADRID   BARCELONA  2019-05-11 08:30:00  2019-05-11 11:15:00
# 3   renfe  MADRID   BARCELONA  2019-04-18 14:30:00  2019-04-18 17:21:00
# 4   renfe  MADRID   BARCELONA  2019-04-28 16:30:00  2019-04-28 19:15:00
#
#   vehicle_class  price      fare
# 0    Preferente   69.4     Promo
# 1       Turista  43.55     Promo
# 2       Turista   85.1     Promo
# 3       Turista  107.7  Flexible
# 4       Turista  107.7  Flexible

# %%
#1 
print(data.dtypes)
print("The object types do not seem reasonable as they should be strings, data time, floats instead of just object")
# Out:
# company          object
# origin           object
# destination      object
# departure        object
# arrival          object
# vehicle_class    object
# price            object
# fare             object
# dtype: object
# The object types do not seem reasonable as they should be strings, data time, floats instead of just object

# %%
#2
#data["price"]
data["price"].value_counts()
# Out:
# price
# price    3875
# 76.3     3794
# 85.1     3615
# 107.7    2845
# 53.4     2719
#          ...
# 98.01       1
# 98.2        1
# 69.05       1
# 19.75       1
# 61.15       1
# Name: count, Length: 389, dtype: int64

# %%
#3
data[(data["price"] == "price")]
# Out:
#        company  origin  destination  departure  arrival  vehicle_class  price  \
# 69     company  origin  destination  departure  arrival  vehicle_class  price
# 146    company  origin  destination  departure  arrival  vehicle_class  price
# 209    company  origin  destination  departure  arrival  vehicle_class  price
# 287    company  origin  destination  departure  arrival  vehicle_class  price
# 347    company  origin  destination  departure  arrival  vehicle_class  price
# ...        ...     ...          ...        ...      ...            ...    ...
# 85903  company  origin  destination  departure  arrival  vehicle_class  price
# 85908  company  origin  destination  departure  arrival  vehicle_class  price
# 85921  company  origin  destination  departure  arrival  vehicle_class  price
# 85934  company  origin  destination  departure  arrival  vehicle_class  price
# 85942  company  origin  destination  departure  arrival  vehicle_class  price
#
#        fare
# 69     fare
# ...

# %%
df = data[(data["price"]!="price")] # dropping columns where price input was price

# %%
#4
data["price"] = data["price"].astype(np.float32)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 2
#       1 #4
# ----> 2 data["price"] = data["price"].astype(np.float32)
#
# File ~\anaconda3\envs\dhp\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\envs\dhp\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %% [markdown]
# Missing Values

# %%
#2
data.isna()
# Out:
#        company  origin  destination  departure  arrival  vehicle_class  price  \
# 0        False   False        False      False    False          False  False
# 1        False   False        False      False    False          False  False
# 2        False   False        False      False    False          False  False
# 3        False   False        False      False    False          False  False
# 4        False   False        False      False    False          False  False
# ...        ...     ...          ...        ...      ...            ...    ...
# 85943    False   False        False      False    False          False  False
# 85944    False   False        False      False    False          False  False
# 85945    False   False        False      False    False          False  False
# 85946    False   False        False      False    False          False  False
# 85947    False   False        False      False    False          False  False
#
#         fare
# 0      False
# ...

# %%
#3
data.info()
print("The missing values are in: vehicle_class, price, fare.")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85948 entries, 0 to 85947
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   company        85948 non-null  object
#  1   origin         85948 non-null  object
#  2   destination    85948 non-null  object
#  3   departure      85948 non-null  object
#  4   arrival        85948 non-null  object
#  5   vehicle_class  77116 non-null  object
#  6   price          72769 non-null  string
#  7   fare           77116 non-null  object
# dtypes: object(7), string(1)
# memory usage: 5.2+ MB
# The missing values are in: vehicle_class, price, fare.

# %%
data.dropna(subset = ['arrival', 'vehicle_class', 'fare'], how='all', inplace = True)

# %%
data[['vehicle_class', 'fare', 'price']].groupby(['vehicle_class', 'fare']).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\envs\dhp\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\anaconda3\envs\dhp\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\anaconda3\envs\dhp\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
# ...
